# %% [markdown]
# <a href="https://colab.research.google.com/github/luccapanel1-star/Google-Colab/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# Classe Livro
class Livro:
    def __init__(self,titulo,autor,genero,quantidade):
        self.titulo=titulo
        self.autor=autor
        self.genero=genero
        self.quantidade=quantidade
# Lista para armazenar os livros
livros=[]
# Função para cadastrar livro
def cadastrar_livro():
    titulo=input("Digite o título: ")
    autor=input("Digite o autor: ")
    genero=input("Digite o gênero: ")
    quantidade=int(input("Digite a quantidade disponível: "))
    livro=Livro(titulo,autor,genero,quantidade)
    livros.append(livro)
    print("Livro cadastrado com sucesso!")
# Função para listar os livros
def listar_livros():
    if len(livros)==0:
        print("Nenhum livro cadastrado.")
    else:
        for livro in livros:
            print("Título:",livro.titulo)
            print("Autor:",livro.autor)
            print("Gênero:",livro.genero)
            print("Quantidade:",livro.quantidade)
# Função para buscar livro pelo título
def buscar_livro():
    titulo=input("Digite o título para buscar: ")
    encontrado=False
    for livro in livros:
        if livro.titulo.lower()==titulo.lower():
            print("Livro encontrado!")
            print("Título:",livro.titulo)
            print("Autor:",livro.autor)
            print("Gênero:",livro.genero)
            print("Quantidade:",livro.quantidade)
            encontrado=True
    if encontrado==False:
        print("Livro não encontrado.")
# Função para gerar gráfico
def gerar_grafico():
    generos={}
    for livro in livros:
        if livro.genero in generos:
            generos[livro.genero]+=livro.quantidade
        else:
            generos[livro.genero]=livro.quantidade
    plt.bar(generos.keys(),generos.values())
    plt.title("Quantidade de Livros por Gênero")
    plt.xlabel("Gênero")
    plt.ylabel("Quantidade")
    plt.show()
# Menu do sistema
while True:
    print("\n1 - Cadastrar livro")
    print("2 - Listar livros")
    print("3 - Buscar livro")
    print("4 - Gerar gráfico")
    print("5 - Sair")
    opcao=input("Escolha uma opção: ")
    if opcao=="1":
        cadastrar_livro()
    elif opcao=="2":
        listar_livros()
    elif opcao=="3":
        buscar_livro()
    elif opcao=="4":
        gerar_grafico()
    elif opcao=="5":
        print("Sistema encerrado.")
        break
    else:
        print("Opção inválida.")
# Out:
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# 4 - Gerar gráfico
# 5 - Sair
# Livro cadastrado com sucesso!
#
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# 4 - Gerar gráfico
# 5 - Sair
# Livro cadastrado com sucesso!
#
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# 4 - Gerar gráfico
# 5 - Sair
# Livro cadastrado com sucesso!
#
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# 4 - Gerar gráfico
# 5 - Sair
# Livro cadastrado com sucesso!
#
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# 4 - Gerar gráfico
# 5 - Sair
# Título: Dom Casmurro
# Autor: Machado de Assis
# Gênero: Romance
# Quantidade: 5
# Título: Harry Potter
# Autor: J.K. Rowling
# Gênero: Fantasia
# Quantidade: 8
# Título: O Hobbit
# Autor: J.R.R. Tolkien
# Gênero: Fantasia
# Quantidade: 4
# Título: O Pequeno Príncipe
# Autor: Antoine de Saint-Exupéry
# Gênero: Aventura
# Quantidade: 6
#
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# ...
