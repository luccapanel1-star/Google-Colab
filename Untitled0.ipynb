# %% [markdown]
# <a href="https://colab.research.google.com/github/luccapanel1-star/Google-Colab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hellow World")
# Out:
# Hellow World

# %% [markdown]
# #u1_a2

# %%
print(10>5)
True
# Out:
# True
# True

# %%
print(5>10)
# Out:
# False

# %%
print(7==7)
# Out:
# True

# %%
print(7!=7)
# Out:
# False

# %%
#guardando informações
idade = 18
e_maior_de_idade = idade >=18
print(e_maior_de_idade)
# Out:
# True

# %%
idade = 20

if idade < 13:
    print("Você é uma criança.")
elif idade < 18:
    print("Você é um adolescente.")
elif idade < 60:
    print("Você é um adulto.")
else:
    print("Você é um idoso.")
# Out:
# Você é um adulto.

# %%
print(True and False)
# Out:
# False

# %%
print(True or True)
# Out:
# True

# %%
idade = 23

if idade < 10:
    print("Você é uma criança")
elif idade < 18:
    print("Você é um adolescente")
else:
    print("Você é um adulto")
# Out:
# Você é um adulto

# %%
#Bem-vindo à Máquina de Venda Automática de Ingressos de Cinema!
#Solicita a idade do cliente
Idade = int(input("Digite sua idade: "))
if Idade < 12:
  print("Recomendamos o filme infantil Toy Store.")
elif 12 <= Idade < 18:
  print("Recomendamos o filme adolescente Vingadores.")
else:
  print("Recomendamos o Filme emocionante A Odisseia.")
# Out:
# Digite sua idade: 10
# Recomendamos o filme infantil Toy Store.

# %%
# Verifica a disponibilidade de ingressos
quantidade_ingressos =10 # Suponha que haja 10 ingressos disponíveis:
if quantidade_ingressos >0:
  print("Ingressos estão disponíveis. Divirta-se no cinema!")
else:
  print("Desculpe, todos os ingressos estão esgotados para hoje.")
# Out:
# Ingressos estão disponíveis. Divirta-se no cinema!
